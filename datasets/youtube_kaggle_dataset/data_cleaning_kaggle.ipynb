# %% [markdown]
# # Cleaning kaggle dataset
#
# This notebook contains code to clean up [YouTube Trending Video Dataset from Kaggle](https://www.kaggle.com/rsrishav/youtube-trending-video-dataset).

# %%
import numpy as np
import pandas as pd

# %%
datasets = ["data/BR_youtube_trending_data.csv",
            "data/CA_youtube_trending_data.csv",
            "data/DE_youtube_trending_data.csv",
            "data/FR_youtube_trending_data.csv",
            "data/GB_youtube_trending_data.csv",
            "data/IN_youtube_trending_data.csv",
            "data/JP_youtube_trending_data.csv",
            "data/KR_youtube_trending_data.csv",
            "data/MX_youtube_trending_data.csv",
            "data/RU_youtube_trending_data.csv",
            "data/US_youtube_trending_data.csv"]

# %% [markdown]
# ## Combine datasets from all countries

# %%
def combine_datasets(filenames):
    """ Concatenete all dataframes from 'filenames' and reset index """
    
    list_of_df = []

    for filename in filenames:
        current_df = pd.read_csv(filename,
                                 parse_dates=['publishedAt', 'trending_date'])
        list_of_df.append(current_df)

    all_df = pd.concat(list_of_df)
    all_df.reset_index(drop=True, inplace=True)
        
    return all_df

# %%
combined_df = combine_datasets(datasets)
combined_df
# Out:
#             video_id                                              title  \
# 0        s9FH4rDMvds     LEVEI UM FORA? FINGI ESTAR APAIXONADO POR ELA!
# 1        jbGRowa5tIk                          ITZY “Not Shy” M/V TEASER
# 2        3EfkCrXKZNs                      Oh Juliana PARÓDIA - MC Niack
# 3        gBjox7vn3-g   Contos de Runeterra: Targon | A Estrada Tortuosa
# 4        npoUGx7UW7o  Entrevista com Thammy Miranda | The Noite (10/...
# ...              ...                                                ...
# 1074413  bgbSheoeOr0  POV your ring changes colors to show the dista...
# 1074414  Q0oOtWE3Qfc  Soulmate controls your….✋😳 (PART 2) #christmas...
# 1074415  gr6hsqv7ofY                        How to never lose in Storm!
# 1074416  V9IXwTLbo7M  How the sounds of Poppy Playtime were actually...
# 1074417  3px1NsXLrzk  Websites you should NOT visit 💻 w OnlyJayus - ...
#
#                       publishedAt                 channelId  \
# 0       2020-08-11 22:21:49+00:00  UCGfBwrCoi9ZJjKiUK8MmJNw
# 1       2020-08-11 15:00:13+00:00  UCaO6TYtlC8U5ttz62hTrZgg
# 2       2020-08-10 14:59:00+00:00  UCoXZmVma073v5G1cW82UKkA
# 3       2020-08-11 15:00:09+00:00  UC6Xqz2pm50gDCORYztqhDpg
# 4       2020-08-11 20:04:02+00:00  UCEWOoncsrmirqnFqxer9lmA
# ...                           ...                       ...
# 1074413 2021-12-09 17:15:00+00:00  UC_joBA9YIuldNdcz_q9T0uA
# 1074414 2021-12-10 01:30:13+00:00  UC_oMKGSjJp838-WKqp0phiQ
# 1074415 2021-12-08 21:26:24+00:00  UCQFFmHSGuP0SE4YZDNKHwKg
# 1074416 2021-12-08 20:03:57+00:00  UCdVHWfWPwwiOzMHpcwEATmA
# 1074417 2021-12-07 21:44:23+00:00  UC4wOd-OGys-RKbv9FYFGRvA
#
#                          channelTitle  categoryId             trending_date  \
# 0                       Pietro Guedes          22 2020-08-12 00:00:00+00:00
# 1                   JYP Entertainment          10 2020-08-12 00:00:00+00:00
# 2                       As Irmãs Mota          22 2020-08-12 00:00:00+00:00
# 3                League of Legends BR          20 2020-08-12 00:00:00+00:00
# 4        The Noite com Danilo Gentili          23 2020-08-12 00:00:00+00:00
# ...                               ...         ...                       ...
# 1074413                   Eliana Ghen          24 2021-12-13 00:00:00+00:00
# 1074414                Brianna Mizura           1 2021-12-13 00:00:00+00:00
# 1074415                         Birdo          20 2021-12-13 00:00:00+00:00
# 1074416                      Davidlap          24 2021-12-13 00:00:00+00:00
# 1074417                     onlyjayus          20 2021-12-13 00:00:00+00:00
#
#                                                       tags  view_count  \
# 0        pietro|guedes|ingrid|ohara|pingrid|vlog|amigos...      263835
# 1        JYP Entertainment|JYP|ITZY|있지|ITZY Video|ITZY ...     6000070
# 2        OH JULIANA PARÓDIA|MC Niack PARÓDIA|PARÓDIAS|A...     2296748
# 3        Riot|Riot Games|League of Legends|lol|trailer|...      300510
# 4        The Noite|The Noite com Danilo Gentili|Danilo ...      327235
# ...                                                    ...         ...
# 1074413  acting challenge|acting challenge tiktok|elian...      970475
# 1074414                                             [None]     1919806
# 1074415  birdo|birdoisthewordo|twitch|streamer|gamer|li...     1144298
# 1074416  how the sounds of poppy playtime were actually...     1519462
# 1074417  Websites you shouldn’t visit|Cool websites|Cra...     3644791
#
#           likes  dislikes  comment_count  \
# 0         85095       487           4500
# 1        714310     15176          31040
# 2         39761      5484              0
# 3         46222       242           2748
# 4         22059      3972           2751
# ...         ...       ...            ...
# 1074413  128254       872            352
# 1074414  240137      1794            615
# 1074415   85885      1313            237
# 1074416   30150       788           1191
# 1074417  407667      5447           4203
#
#                                          thumbnail_link  comments_disabled  \
# 0        https://i.ytimg.com/vi/s9FH4rDMvds/default.jpg              False
# 1        https://i.ytimg.com/vi/jbGRowa5tIk/default.jpg              False
# 2        https://i.ytimg.com/vi/3EfkCrXKZNs/default.jpg               True
# 3        https://i.ytimg.com/vi/gBjox7vn3-g/default.jpg              False
# 4        https://i.ytimg.com/vi/npoUGx7UW7o/default.jpg              False
# ...                                                 ...                ...
# 1074413  https://i.ytimg.com/vi/bgbSheoeOr0/default.jpg              False
# 1074414  https://i.ytimg.com/vi/Q0oOtWE3Qfc/default.jpg              False
# 1074415  https://i.ytimg.com/vi/gr6hsqv7ofY/default.jpg              False
# 1074416  https://i.ytimg.com/vi/V9IXwTLbo7M/default.jpg              False
# 1074417  https://i.ytimg.com/vi/3px1NsXLrzk/default.jpg              False
#
#          ratings_disabled                                        description
# 0                   False  Salve rapaziada, neste vídeo me declarei pra e...
# 1                   False  ITZY Not Shy M/V[ITZY Official] https://www.yo...
# 2                   False  Se inscrevam meus amores! 📬 Quer nos mandar al...
# 3                   False  Você se unirá aos Lunari e aos Solari em Targo...
# 4                   False  Danilo Gentili recebe Thammy Miranda. Após pas...
# ...                   ...                                                ...
# 1074413             False                                                NaN
# 1074414             False  POV: Each week your soulmate gets to control s...
# 1074415             False  Don't forget to like, comment, and subscribe i...
# 1074416             False  I tried to recreate the sounds from the Poppy ...
# 1074417             False  Subscribe: https://bit.ly/30dW7xy​ | HIT THE L...
#
# [1074418 rows x 16 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074418 entries, 0 to 1074417
# Data columns (total 16 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   video_id           1074418 non-null  object
#  1   title              1074418 non-null  object
#  2   publishedAt        1074418 non-null  datetime64[ns, UTC]
#  3   channelId          1074418 non-null  object
#  4   channelTitle       1074417 non-null  object
#  5   categoryId         1074418 non-null  int64
#  6   trending_date      1074418 non-null  datetime64[ns, UTC]
#  7   tags               1074418 non-null  object
#  8   view_count         1074418 non-null  int64
#  9   likes              1074418 non-null  int64
#  10  dislikes           1074418 non-null  int64
#  11  comment_count      1074418 non-null  int64
#  12  thumbnail_link     1074418 non-null  object
#  13  comments_disabled  1074418 non-null  bool
#  14  ratings_disabled   1074418 non-null  bool
#  15  description        1050203 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](2), int64(5), object(7)
# memory usage: 116.8+ MB

# %%
# dataset size - 1,074,418 rows, 
# but it contains only 199,728 unique video IDs
len(combined_df['video_id'].unique())
# Out:
# 199728

# %% [markdown]
# ## Clean dataset

# %%
def clean_kaggle_dataset(dataset):
    """ 
    Clean YouTube Kaggle dataset:
        - Replace NaN in description with space
        - Delete missing values
        - Keep records only with unique video IDs 
          with the maximum number of views (the latest request)
        - Delete entries where comments_disabled=True or ratings_disabled=True
        - Convert "tags" field from list of strings to string
        - Delete non-ASCII characters and non-English from text columns
        - Rename columns to snake case, reorder add empty 'comments' column
        - Delete non-relevant columns
        - Reset index
    """

    clean_df = dataset.copy(deep=True)

    # Replace NaN in description with space
    clean_df["description"].fillna(" ", inplace=True)
    # Delete all rows with a missing values if any
    clean_df.dropna(inplace=True)

    # primary_key - unique 'video_id' with the largest number of views
    primary_key = clean_df.groupby("video_id")["view_count"].idxmax()
    # keep only most relevant records
    clean_df = clean_df.loc[primary_key]

    # delete rows with comments_disabled=True or ratings_disabled=True
    clean_df = clean_df[(clean_df['comments_disabled'] == False) &
                        (clean_df['ratings_disabled'] == False)]

    # Replace [None] in tags with space
    clean_df.loc[clean_df['tags'] == '[None]', 'tags'] = ' '
    # split tags with '|' and convert list to one string
    clean_df['tags'] = [' '.join(tag)
                        for tag in clean_df['tags'].str.split('|')]

    printable = '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n'
    # delete non-ASCII and non-English characters
    for text_column in ['title', 'channelTitle', 'description', 'tags']:
        # for all rows in the column apply a filter
        # that only leaves characters from 'printable'
        # since filter does not return a string, then you need to use the join method
        clean_df[text_column] = clean_df[text_column].apply(
            lambda x: ''.join(filter(lambda xi: xi in printable, x)))

    # if there is not a single letter left
    # in the title of the video or in the channel title
    # the video is definitely not in English
    symbols = [c for c in "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"]
    clean_df = clean_df[clean_df['title'].str.contains('|'.join(symbols))]
    clean_df = clean_df[clean_df['channelTitle'].str.contains(
        '|'.join(symbols))]

    # create new empty column
    clean_df['comments'] = " "

    # rename columns to match snake case
    clean_df.rename(columns={'channelTitle': 'channel_title',
                             'publishedAt': 'published_at',
                             'channelId': 'channel_id'}, inplace=True)

    # delete non-relevant columns
    clean_df.drop(['categoryId', 'trending_date',
                   'thumbnail_link', 'comments_disabled',
                   'ratings_disabled'], axis=1, inplace=True)

    clean_df = clean_df.reindex(columns=['video_id', 'title', 'channel_id', 'channel_title',
                                         'published_at', 'view_count', 'likes', 'dislikes',
                                         'comment_count', 'tags', 'description', 'comments'])

    clean_df.reset_index(drop=True, inplace=True)

    return clean_df

# %%
clean_df = clean_kaggle_dataset(combined_df)
clean_df
# Out:
#            video_id                                              title  \
# 0       --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1       --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2       --2Us2lFR8Y        JE CONSTRUIS UNE PICE SECRTE DANS MA MAISON
# 3       --38nmkJJmE  Je suis retourn en CLASSE en me DGUISANT en PR...
# 4       --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# ...             ...                                                ...
# 137857  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 137858  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 137859  zztGoiavb5c                              YGX  !    VOGUE MEETS
# 137860  zzuXBF16ZQg                   Dmn qruplamas mhasiry alnd - RSM
# 137861  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                       channel_id       channel_title  \
# 0       UC6UL29enLNe4mqwTfAyeNuw          Bundesliga
# 1       UCGIelM2Dj3zza3xyV3pL3WQ           MigosVEVO
# 2       UCgl_xdd0kH27vMIZnE-_17w               ALEKS
# 3       UCugeH-Bmo9a5-Jnbt9X-3bA       [ Unchained ]
# 4       UClBKH8yZRcM4AsRjDVEdjMg  Television Academy
# ...                          ...                 ...
# 137857  UCuhAUMLzJxlP1W7mEk0_6lA             MAMAMOO
# 137858  UC8NjnNWMsRqq11NYvHAQb1g      Master Podcast
# 137859  UC2DHU9RPlx9DpY0pMfL7jBg         VOGUE KOREA
# 137860  UCiNdMWXMS7zjvm0QApujZbg              Mir TV
# 137861  UCEg25rdRZXg32iwai6N6l0w   Tottenham Hotspur
#
#                     published_at  view_count   likes  dislikes  comment_count  \
# 0      2021-07-01 10:00:00+00:00      433340   11276       110           1083
# 1      2021-06-10 16:00:00+00:00     8034045  281817      4675          17321
# 2      2021-02-11 17:02:05+00:00      705147   94116      1105           4666
# 3      2021-03-28 11:14:36+00:00      633309   61975       993           3001
# 4      2021-09-20 01:03:32+00:00      682609    8029       369            723
# ...                          ...         ...     ...       ...            ...
# 137857 2021-06-02 09:00:10+00:00     9885830  614391      3543          81258
# 137858 2020-10-20 20:59:30+00:00      139077   12937       621           1143
# 137859 2021-10-26 14:00:34+00:00      724192   21474       126           1078
# 137860 2020-09-30 08:34:47+00:00       35253     853        48             81
# 137861 2021-05-23 21:00:31+00:00     2144129   32744       823           2037
#
#                                                      tags  \
# 0       football soccer ftbol alemn Bundesliga season ...
# 1       Migos Avalanche Quality Control Music/Motown R...
# 2       maison secret pice secrte secrte constuire je ...
# 3       among us nouvelle map among us mise a jour amo...
# 4
# ...                                                   ...
# 137857  MAMAMOO  WAW  WAW MAMAMOO WAW Where Are We Now...
# 137858  master masterpodcast lord lord vinheteiro z z ...
# 137859                           ygx      blackpink ygx
# 137860
# 137861  Spurs Tottenham Hotspur   Tottenham Leicester ...
#
#                                               description comments
# 0       Enjoy the best skills and goals from Jadon San...
# 1       Watch the the official video for Migos - Avala...
# 2       Aprs avoir ragis  PLEIN de pices SECRTES chez ...
# 3       CODE UNCHAINED dans la boutique # ad Mon disco...
# 4       Hannah Waddingham wins the Emmy for Supporting...
# ...                                                   ...      ...
# 137857  [MV]  (MAMAMOO) - Where Are We NowInstagram: h...
# 137858  DOCTOR HAIRhttps://www.thedoctorhair.com/?fbcl...
# 137859  #VogueMeets #YGXYGX    YGX   ? #  ?     YGX   ...
# 137860  Cbhnin Adr-Trtr istiqamtind mhasiry alnan ermn...
# 137861  Two minute highlights from Tottenham Hotspur's...
#
# [137862 rows x 12 columns]

# %%
# check that group by worked correctly
len(clean_df['video_id'].unique())
# Out:
# 137862

# %%
# save dataset
clean_df.to_csv('data/youtube_kaggle_dataset.csv', index=False, header=True)
